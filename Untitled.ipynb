# %%
import yfinance as yf
import pandas as pd
from tqdm import tqdm
import logging

# Define ANSI escape sequences for colors
class Colors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKCYAN = '\033[96m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'

# Configure logging to suppress warnings and errors
logging.basicConfig(level=logging.CRITICAL)

symbols_csv = pd.read_csv("symbols.csv")
list_of_symbols = symbols_csv["symbol"].tolist()
str_of_all_symbols = " ".join([symbol.lower() for symbol in list_of_symbols])

ticker = yf.Ticker("MSFT")
data = ticker.info
columns = list(data.keys())
df = pd.DataFrame(columns=["symbols"] + columns)
df["symbols"] = list_of_symbols

tickers = yf.Tickers(str_of_all_symbols)
li = list_of_symbols[-10:]  # Limiting to the last 10 symbols for testing
column_names = [i for i in df.columns]
for symbol in tqdm(li, desc="\033[94mProcessing symbols\033[0m", ncols=100):
    # try:
        data = tickers.tickers[symbol].info
        data_df = pd.DataFrame(data=[data])
        data_df["symbols"] = symbol
data_df.head()
#         df.head()
#         # Rename columns to avoid duplicates
#         #data_df = data_df.rename(columns=lambda x: f"{x}_new" if x in df.columns else x)
#         df = pd.merge(df, data_df, on=column_names, how='inner')
#         print(df)
#     # except Exception as e:
#     #     if "404" in str(e):
#     #         tqdm.write(f"{Colors.WARNING}Symbol {symbol} not found. Skipping.{Colors.ENDC}")
#     #     else:
#     #         tqdm.write(f"{Colors.FAIL}Error processing {symbol}: {e}{Colors.ENDC}")

# print(f"\033[92mWriting to excel...\033[0m")
# df.to_excel('database.xlsx', index=False)
# print(f"{Colors.OKGREEN}Data successfully saved to database.xlsx{Colors.ENDC}")
# Out:
# Processing symbols: 100%|███████████████████████████████████████████| 10/10 [00:03<00:00,  2.83it/s]
#              address1       city state    zip        country         phone  \
# 0  9655 Maroon Circle  Englewood    CO  80112  United States  303 703 4906
#
#             fax                website              industry  \
# 0  800 495 6695  https://www.zynex.com  Medical Distribution
#
#             industryKey  ... freeCashflow operatingCashflow earningsGrowth  \
# 0  medical-distribution  ...     19447876          17890000         -0.992
#
#   revenueGrowth grossMargins  ebitdaMargins operatingMargins  \
# 0         0.103      0.79831        0.08291          0.01128
#
#    financialCurrency  trailingPegRatio  symbols
# 0                USD              None     ZYXI
#
# [1 rows x 126 columns]
